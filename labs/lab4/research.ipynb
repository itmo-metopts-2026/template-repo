# %% [markdown]
# # Лабораторная работа №4
#
# **Реализация:** [`model.py`](model.py)
#
# ---

# %% [markdown]
# ### 1. Импорт зависимостей и фиксация случайности

# %%
import sys
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt

# Добавляем корневую директорию labs/ в путь поиска модулей
sys.path.insert(0, str(Path("..").resolve()))

from utils.seed import set_global_seed

# TODO: импортировать модель из model.py
# from model import ...

# Фиксация всех источников случайности
SEED = 42
set_global_seed(SEED)

# Директория для сохранения графиков
FIGURES_DIR = Path("results/figures")
FIGURES_DIR.mkdir(parents=True, exist_ok=True)

print(f"Seed зафиксирован: {SEED}")

# %% [markdown]
# ### 2. Подготовка данных

# %%
# TODO: загрузить или сгенерировать данные

# %% [markdown]
# ### 3. Задание лабораторной

# %%
# TODO: Выполните задание

# %% [markdown]
# ### 4. Визуализация

# %%
# TODO: Визуализируйте результаты

# %% [markdown]
# ### 6. Итоги
#
# <!-- Кратко опишите результаты -->
#
# ---
#
# **Подробный отчёт:** [`report.md`](report.md)
